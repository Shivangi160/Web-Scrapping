# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "http://15.206.143.222/webscrap/demo1.html"

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>Head Of The Page</head>\n<body>\n<p>Simple Paragraph</p>\n</body>\n</html>'

# %%
soup = BeautifulSoup(page.content,'html.parser')
print(soup)

# %%
print(soup.prettify())

# %%
html = list(soup.children)[2]
html

# %%
body = list(html.children)[3]
body

# %%
p = list(body.children)[1]
p

# %%
data = p.get_text()   ### get the text from the tag
data
# Out:
# 'Simple Paragraph'

# %%
type(data)
# Out:
# str

# %%
###########################################################

# %%
url = "http://15.206.143.222/webscrap/demo2.html"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,'html.parser')
print(soup.prettify())

# %%
soup.find('p')
# Out:
# <p>First Paragraph</p>

# %%
soup.find_all('p')
# Out:
# [<p>First Paragraph</p>, <p>Second Paragraph</p>, <p>Third Paragraph</p>]

# %%
data = soup.find_all('p')
for i in data:
  print(i.get_text())

# %%
soup.find_all('head')

# %%
soup.find_all('head')[0].get_text()

# %%
###################################################

# %%
url = "http://15.206.143.222/webscrap/demo3.html"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    A simple page
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     First paragraph.
#    </p>
#    <p class="inner-text">
#     Second paragraph.
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     First outer paragraph.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     Second outer paragraph.
#    </b>
#   </p>
#   <a href="http://www.google.com" id="link1">
#    Google
#   </a>
#   <a href="http://www.facebook.com" id="link2">
#    Facebook
#   </a>
#   <a href="http://www.instagram.com" id="link3">
#    Instagram
#   </a>
#  </body>
# </html>

# %%
### Search by class
soup.find_all('p',class_='inner-text')

# %%
### Search by class
soup.find_all('p',class_='inner-text first-item')
# Out:
# [<p class="inner-text first-item" id="first">
#  First paragraph.
#  </p>]

# %%
### Search by id
soup.find_all('p',id='first')

# %%
### Search by id
soup.find_all(id='first')
# Out:
# [<p class="inner-text first-item" id="first">
#  First paragraph.
#  </p>]

# %%
### Search by class
soup.find_all(class_='inner-text')
# Out:
# [<p class="inner-text first-item" id="first">
#  First paragraph.
#  </p>, <p class="inner-text">
#  Second paragraph.
#  </p>]

# %%
data = soup.find_all('a',id='link1')
data
# Out:
# <a href="http://www.google.com" id="link1">Google</a>

# %%
data[0].get_text()
# Out:
# 'Google'

# %%
data[0].get('id')
# Out:
# 'link1'

# %%
data[0].get('href')
# Out:
# 'http://www.google.com'

# %%
soup.select('p')
# Out:
# [<p class="inner-text first-item" id="first">
#  First paragraph.
#  </p>, <p class="inner-text">
#  Second paragraph.
#  </p>, <p class="outer-text first-item" id="second">
#  <b>
#  First outer paragraph.
#  </b>
#  </p>, <p class="outer-text">
#  <b>
#  Second outer paragraph.
#  </b>
#  </p>]

# %%
soup.select('p.inner-text')
# Out:
# [<p class="inner-text first-item" id="first">
#  First paragraph.
#  </p>, <p class="inner-text">
#  Second paragraph.
#  </p>]

# %%
soup.select('p#first')
# Out:
# [<p class="inner-text first-item" id="first">
#  First paragraph.
#  </p>]

# %%
soup.select('p#second b')[0].get_text()
# Out:
# '\nFirst outer paragraph.\n'

# %%
soup.find_all('p',id='second')[0].get_text()
# Out:
# '\n\nFirst outer paragraph.\n\n'

# %%
soup.select('p#second b')[0].get_text().replace("\n","")
# Out:
# 'First outer paragraph.'

# %%
soup.select('p#second b')[0].get_text().lstrip("\n")
# Out:
# 'First outer paragraph.\n'

# %%
soup.select('p#second b')[0].get_text().rstrip("\n")
# Out:
# '\nFirst outer paragraph.'

# %%
soup.select('p#second b')[0].get_text().strip("\n")
# Out:
# 'First outer paragraph.'
